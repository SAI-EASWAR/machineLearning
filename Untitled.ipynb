# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")

# %%
selected_col = ['LotArea','BedroomAbvGr','FullBath','SalePrice']
data = df[selected_col].copy()

# %%
data.isnull().any()
# Out:
# LotArea         False
# BedroomAbvGr    False
# FullBath        False
# SalePrice       False
# dtype: bool

# %%
for column in data.columns[:3]:
    plt.xlabel(column)
    plt.ylabel(data.columns[-1])
    plt.scatter(data[column],data[data.columns[-1]],marker='o',alpha=0.3)
    plt.title('Scatter Plot: Lot Area vs Sale Price')
    plt.grid(True)
    plt.show()

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
data.shape
# Out:
# (1460, 4)

# %%
X = data.drop(["SalePrice"],axis=1)
Y = data.SalePrice

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
error = mean_squared_error(y_test,predicted)

# %%
error
# Out:
# 4291666071.1142035

# %%
r2 = r2_score(y_test,predicted)

# %%
r2
# Out:
# 0.35193383983776216

# %%
k_fold = 5
cv_scores = cross_val_score(model, X, Y, cv=k_fold, scoring='r2')

# %%
print("Mean MSE:", np.mean(cv_scores))
# print("Standard Deviation of MSE:", np.std(cv_scores))
# Out:
# Mean MSE: -4220922157.2428994
